# %% [markdown]
# # Section 1

# %% [markdown]
# # Question 1

# %%
# importing requied libraries
import pandas
from keras.models import Sequential
from keras.layers import Dense, Activation

# %%
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np

# %% [markdown]
# i

# %%
# load dataset using pandas
dataset = pd.read_csv("/content/diabetes.csv", header=None).values

# %%
# Splitting input dataset into training and test sets using  train_test_split function from sklearn library
X_train, X_test, Y_train, Y_test = train_test_split(dataset[:,0:8], dataset[:,8],
                                                    test_size=0.25, random_state=87)

# %%
# creating a neual network with 20 Layers to train on input data
np.random.seed(155)
my_first_nn = Sequential() # create model
my_first_nn.add(Dense(20, input_dim=8, activation='relu')) # hidden layer
my_first_nn.add(Dense(1, activation='sigmoid')) # output layer
my_first_nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['acc'])
my_first_nn_fitted = my_first_nn.fit(X_train, Y_train, epochs=100,
                                     initial_epoch=0)
# Out:
# Epoch 1/100
# 18/18 [==============================] - 1s 3ms/step - loss: 10.8954 - acc: 0.3576
# Epoch 2/100
# 18/18 [==============================] - 0s 4ms/step - loss: 5.0677 - acc: 0.4479
# Epoch 3/100
# 18/18 [==============================] - 0s 3ms/step - loss: 3.4854 - acc: 0.5903
# Epoch 4/100
# 18/18 [==============================] - 0s 4ms/step - loss: 2.9714 - acc: 0.5104
# Epoch 5/100
# 18/18 [==============================] - 0s 4ms/step - loss: 2.7262 - acc: 0.5104
# Epoch 6/100
# 18/18 [==============================] - 0s 3ms/step - loss: 2.5103 - acc: 0.5278
# Epoch 7/100
# 18/18 [==============================] - 0s 3ms/step - loss: 2.3316 - acc: 0.5104
# Epoch 8/100
# 18/18 [==============================] - 0s 3ms/step - loss: 2.1691 - acc: 0.5573
# Epoch 9/100
# 18/18 [==============================] - 0s 3ms/step - loss: 2.0064 - acc: 0.5469
# Epoch 10/100
# 18/18 [==============================] - 0s 4ms/step - loss: 1.8837 - acc: 0.5417
# Epoch 11/100
# ...

# %%
# evaluting model to get Accuracy
print(my_first_nn.summary())
print(my_first_nn.evaluate(X_test, Y_test))
# Out:
# Model: "sequential_17"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_37 (Dense)            (None, 20)                180
#
#  dense_38 (Dense)            (None, 1)                 21
#
# ...
# Total params: 201 (804.00 Byte)
# Trainable params: 201 (804.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6429 - acc: 0.6615
# [0.6429306864738464, 0.6614583134651184]

# %% [markdown]
# Increasing number of layers to 50 to check performance
#
# Dense(50) to increase nn layers to 50

# %%
np.random.seed(155)
my_first_nn = Sequential() # create model
my_first_nn.add(Dense(50, input_dim=8, activation='relu')) # hidden layer
my_first_nn.add(Dense(1, activation='sigmoid')) # output layer
my_first_nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['acc'])
my_first_nn_fitted = my_first_nn.fit(X_train, Y_train, epochs=100,
                                     initial_epoch=0)
# Out:
# Epoch 1/100
# 18/18 [==============================] - 1s 2ms/step - loss: 5.8734 - acc: 0.5174
# Epoch 2/100
# 18/18 [==============================] - 0s 2ms/step - loss: 1.7955 - acc: 0.5295
# Epoch 3/100
# 18/18 [==============================] - 0s 2ms/step - loss: 1.1050 - acc: 0.5885
# Epoch 4/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.8306 - acc: 0.6458
# Epoch 5/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.7439 - acc: 0.6736
# Epoch 6/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6987 - acc: 0.6823
# Epoch 7/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6904 - acc: 0.6719
# Epoch 8/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6779 - acc: 0.6823
# Epoch 9/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.7341 - acc: 0.6389
# Epoch 10/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6730 - acc: 0.6788
# Epoch 11/100
# ...

# %%
print(my_first_nn.summary())
print(my_first_nn.evaluate(X_test, Y_test))
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_6 (Dense)             (None, 50)                450
#
#  dense_7 (Dense)             (None, 1)                 51
#
# ...
# Total params: 501 (1.96 KB)
# Trainable params: 501 (1.96 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# 6/6 [==============================] - 0s 3ms/step - loss: 0.5978 - acc: 0.7083
# [0.5978018641471863, 0.7083333134651184]

# %% [markdown]
# Old evalution metric
# [0.6153196692466736, 0.6770833134651184]
#
# Evaluation scores after increasing Dense Layers to 50 from 20
# [0.5978018641471863, 0.7083333134651184]
#
# model performance increased by 0.3 or 30% when dense layers increaased.

# %% [markdown]
# # Question 2
#
# ### using breast cancer dataset

# %%
# loading breastcancer dataset and removed columns Unnamed: 32 and id which are not useful
dataset = pd.read_csv("/content/breastcancer.csv")
x = dataset.drop(['diagnosis', 'Unnamed: 32', 'id'], axis=1) # features
y = dataset['diagnosis'] # target column diagnosis

# %% [markdown]
# Applied Label Encoder to convert Diagnosis (target) column to numeric column

# %%
# Encoding the Y label to convert it to numerical column
from sklearn.preprocessing import LabelEncoder
labelencoder_y = LabelEncoder()
y = labelencoder_y.fit_transform(y)

# %%
# split data into train and test datasets
X_train, X_test, Y_train, Y_test = train_test_split(x, y,
                                                    test_size=0.25, random_state=87)

# %%
# model training
np.random.seed(110)
my_first_nn = Sequential() # create model
my_first_nn.add(Dense(20, input_dim=30, activation='relu')) # hidden layer
my_first_nn.add(Dense(1, activation='sigmoid')) # output layer
my_first_nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['acc'])
my_first_nn_fitted = my_first_nn.fit(X_train, Y_train, epochs=100,
                                     initial_epoch=0)
# Out:
# Epoch 1/100
# 14/14 [==============================] - 1s 2ms/step - loss: 16.6385 - acc: 0.6549
# Epoch 2/100
# 14/14 [==============================] - 0s 2ms/step - loss: 1.3427 - acc: 0.6901
# Epoch 3/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4767 - acc: 0.8615
# Epoch 4/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4981 - acc: 0.8967
# Epoch 5/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3208 - acc: 0.8991
# Epoch 6/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3134 - acc: 0.9108
# Epoch 7/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2989 - acc: 0.9014
# Epoch 8/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3025 - acc: 0.8967
# Epoch 9/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3046 - acc: 0.9108
# Epoch 10/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2923 - acc: 0.9014
# Epoch 11/100
# ...

# %%
print(my_first_nn.summary())
print(my_first_nn.evaluate(X_test, Y_test))
# Out:
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_22 (Dense)            (None, 20)                620
#
#  dense_23 (Dense)            (None, 1)                 21
#
# ...
# Total params: 641 (2.50 KB)
# Trainable params: 641 (2.50 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# 5/5 [==============================] - 0s 3ms/step - loss: 0.5199 - acc: 0.8741
# [0.5198723673820496, 0.8741258978843689]

# %% [markdown]
# # Question 3
#
# ## Normalize the data before feeding the data to the model and check how the normalization change your accuracy (code given below).
# from sklearn.preprocessing import StandardScaler
# sc = StandardScaler()

# %%
dataset = pd.read_csv("/content/breastcancer.csv")
x = dataset.drop(['diagnosis', 'Unnamed: 32', 'id'], axis=1)
y = dataset['diagnosis']

# %%
# Applying Standard Scalar on input Dataset before training
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x = sc.fit_transform(x)

# %%
# Enconding target column to convert it as numeric
from sklearn.preprocessing import LabelEncoder
labelencoder_y = LabelEncoder()
y = labelencoder_y.fit_transform(y)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(x, y,
                                                    test_size=0.25, random_state=87)

# %%
np.random.seed(110)
my_first_nn = Sequential() # create model
my_first_nn.add(Dense(20, input_dim=30, activation='relu')) # hidden layer
my_first_nn.add(Dense(1, activation='sigmoid')) # output layer
my_first_nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['acc'])
my_first_nn_fitted = my_first_nn.fit(X_train, Y_train, epochs=100,
                                     initial_epoch=0)
# Out:
# Epoch 1/100
# 14/14 [==============================] - 1s 2ms/step - loss: 0.4904 - acc: 0.8005
# Epoch 2/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3571 - acc: 0.8732
# Epoch 3/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2787 - acc: 0.9319
# Epoch 4/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2293 - acc: 0.9460
# Epoch 5/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1970 - acc: 0.9531
# Epoch 6/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1739 - acc: 0.9577
# Epoch 7/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1560 - acc: 0.9624
# Epoch 8/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1424 - acc: 0.9648
# Epoch 9/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1311 - acc: 0.9648
# Epoch 10/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1220 - acc: 0.9671
# Epoch 11/100
# ...

# %%
print(my_first_nn.summary())
print(my_first_nn.evaluate(X_test, Y_test))
# Out:
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_24 (Dense)            (None, 20)                620
#
#  dense_25 (Dense)            (None, 1)                 21
#
# ...
# Total params: 641 (2.50 KB)
# Trainable params: 641 (2.50 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# 5/5 [==============================] - 0s 3ms/step - loss: 0.1868 - acc: 0.9650
# [0.1867758333683014, 0.9650349617004395]

# %% [markdown]
# Comparision
#
# Before applying standard scalar to the input dataset we got accuracy as
# 0.8741258978843689 or 87%
#
# After Applying Standard Scalar to scale the input dataset we got accuracy as 0.9650349617004395 or 96%
#
# Accuracy has increased by 9%

# %% [markdown]
# # Section 2

# %% [markdown]
# # Question 1
# ### Use Image Classification on the hand written digits data set (mnist)
# ###1. Plot the loss and accuracy for both training data and validation data using the history object in the source code.

# %%
#importing required libraries
from keras import Sequential
from keras.datasets import mnist
import numpy as np
from keras.layers import Dense
from keras.utils import to_categorical

# %%
# creating train and test data using mnist dataset

(train_images,train_labels),(test_images, test_labels) = mnist.load_data()

print(train_images.shape[1:])
# Out:
# (28, 28)

# %%
#process the data
#1. convert each image of shape 28*28 to 784 dimensional which will be fed to the network as a single feature
dimData = np.prod(train_images.shape[1:])
print(dimData)
train_data = train_images.reshape(train_images.shape[0],dimData)
test_data = test_images.reshape(test_images.shape[0],dimData)
# Out:
# 784

# %%
#convert data to float and scale values between 0 and 1
train_data = train_data.astype('float')
test_data = test_data.astype('float')

# %%
#scale data
train_data /=255.0
test_data /=255.0
#change the labels frominteger to one-hot encoding. to_categorical is doing the same thing as LabelEncoder()
train_labels_one_hot = to_categorical(train_labels)
test_labels_one_hot = to_categorical(test_labels)

# %%
#creating network
model = Sequential()
model.add(Dense(512, activation='relu', input_shape=(dimData,)))
model.add(Dense(512, activation='relu'))
model.add(Dense(10, activation='softmax'))

# %%
model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])
history = model.fit(train_data, train_labels_one_hot, batch_size=256, epochs=10, verbose=1,
                   validation_data=(test_data, test_labels_one_hot))
# Out:
# Epoch 1/10
# 235/235 [==============================] - 7s 26ms/step - loss: 0.2934 - accuracy: 0.9100 - val_loss: 0.2081 - val_accuracy: 0.9323
# Epoch 2/10
# 235/235 [==============================] - 7s 31ms/step - loss: 0.1013 - accuracy: 0.9688 - val_loss: 0.0850 - val_accuracy: 0.9729
# Epoch 3/10
# 235/235 [==============================] - 6s 25ms/step - loss: 0.0642 - accuracy: 0.9802 - val_loss: 0.0763 - val_accuracy: 0.9761
# Epoch 4/10
# 235/235 [==============================] - 7s 31ms/step - loss: 0.0444 - accuracy: 0.9861 - val_loss: 0.0884 - val_accuracy: 0.9733
# Epoch 5/10
# 235/235 [==============================] - 6s 24ms/step - loss: 0.0311 - accuracy: 0.9900 - val_loss: 0.1023 - val_accuracy: 0.9705
# Epoch 6/10
# 235/235 [==============================] - 8s 32ms/step - loss: 0.0234 - accuracy: 0.9925 - val_loss: 0.0644 - val_accuracy: 0.9817
# Epoch 7/10
# ...

# %%
# nuPlot the loss and accuracy for both training data and validation data using the history object in the source code.
import matplotlib.pyplot as plt
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['train', 'validation'])
plt.show()

# %%
# plot accuracy for train data and validation datsets
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.legend(['train', 'validation'])
plt.show()

# %%
model.evaluate(test_data, test_labels_one_hot)
# Out:
# 313/313 [==============================] - 2s 6ms/step - loss: 0.0679 - accuracy: 0.9833
# [0.06791830062866211, 0.983299970626831]

# %% [markdown]
# # Question 2
#
# ###  Plot one of the images in the test data, and then do inferencing to check what is the prediction of the model on that single image.

# %%
# Plot one of the images in the test data, and then do inferencing to check what is the prediction of the model on that single image.
plt.imshow(test_images[0], cmap='gray')
plt.show()

# %%
# inferencing to check what is the prediction of the model on that single image and plot the prediction.
pred = model.predict(test_data[0].reshape(1,784))
pred
# Out:
# 1/1 [==============================] - 0s 59ms/step
# array([[3.8029468e-01, 2.0215721e-03, 4.1151422e-01, 9.9813932e-01,
#         1.3111124e-02, 6.5844756e-01, 1.0252734e-06, 1.0000000e+00,
#         2.7192530e-01, 9.6246368e-01]], dtype=float32)

# %% [markdown]
# # QUestion 3

# %%
# We had used 2 hidden layers and Relu activation. Try to change the number of hidden layer and the activation to tanh or sigmoid and see what happens

#creating network
model = Sequential()
model.add(Dense(1024, activation='tanh', input_shape=(dimData,)))
model.add(Dense(1024, activation='tanh'))
model.add(Dense(10, activation='sigmoid'))

# %%
model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])
history = model.fit(train_data, train_labels_one_hot, batch_size=256, epochs=10, verbose=1,
                   validation_data=(test_data, test_labels_one_hot))
# Out:
# Epoch 1/10
# 235/235 [==============================] - 20s 77ms/step - loss: 0.4574 - accuracy: 0.8636 - val_loss: 0.3108 - val_accuracy: 0.8997
# Epoch 2/10
# 235/235 [==============================] - 23s 98ms/step - loss: 0.1852 - accuracy: 0.9443 - val_loss: 0.1471 - val_accuracy: 0.9563
# Epoch 3/10
# 235/235 [==============================] - 18s 76ms/step - loss: 0.1096 - accuracy: 0.9671 - val_loss: 0.0974 - val_accuracy: 0.9674
# Epoch 4/10
# 235/235 [==============================] - 17s 74ms/step - loss: 0.0769 - accuracy: 0.9761 - val_loss: 0.1130 - val_accuracy: 0.9639
# Epoch 5/10
# 235/235 [==============================] - 20s 83ms/step - loss: 0.0553 - accuracy: 0.9827 - val_loss: 0.1091 - val_accuracy: 0.9640
# Epoch 6/10
# 235/235 [==============================] - 17s 74ms/step - loss: 0.0414 - accuracy: 0.9873 - val_loss: 0.1042 - val_accuracy: 0.9657
# Epoch 7/10
# ...

# %%
model.evaluate(test_data, test_labels_one_hot)
# Out:
# 313/313 [==============================] - 2s 6ms/step - loss: 0.0697 - accuracy: 0.9792
# [0.06967434287071228, 0.979200005531311]

# %% [markdown]
# # Comparison by changing Dense Layers and activation function
#
# when using relu activation function and 512 Dense Layers got an accuracy of 0.983299970626831 or 98.32%
#
# when using tanh and sigmoid and increasing dense layers to 1024 got an accuracy of  0.979200005531311 or 97.92%
#
#
# there is not much differnce when changing the activation function and Dense layers. Both yeilded the same accuracy

# %% [markdown]
# # Question 4

# %%
# Run the same code without scaling the images and check the performance?
from keras import Sequential
from keras.datasets import mnist
import numpy as np
from keras.layers import Dense
from keras.utils import to_categorical

(train_images,train_labels),(test_images, test_labels) = mnist.load_data()

print(train_images.shape[1:])
#process the data
#1. convert each image of shape 28*28 to 784 dimensional which will be fed to the network as a single feature
dimData = np.prod(train_images.shape[1:])
print(dimData)
train_data = train_images.reshape(train_images.shape[0],dimData)
test_data = test_images.reshape(test_images.shape[0],dimData)

#convert data to float and scale values between 0 and 1
train_data = train_data.astype('float')
test_data = test_data.astype('float')

#scale data
# train_data /=255.0
# test_data /=255.0


#change the labels frominteger to one-hot encoding. to_categorical is doing the same thing as LabelEncoder()
train_labels_one_hot = to_categorical(train_labels)
test_labels_one_hot = to_categorical(test_labels)

#creating network
model = Sequential()
model.add(Dense(512, activation='relu', input_shape=(dimData,)))
model.add(Dense(512, activation='relu'))
model.add(Dense(10, activation='softmax'))

model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])
history = model.fit(train_data, train_labels_one_hot, batch_size=256, epochs=10, verbose=1,
                   validation_data=(test_data, test_labels_one_hot))
# Out:
# (28, 28)
# 784
# Epoch 1/10
# 235/235 [==============================] - 8s 32ms/step - loss: 5.8918 - accuracy: 0.8757 - val_loss: 0.7434 - val_accuracy: 0.9328
# Epoch 2/10
# 235/235 [==============================] - 6s 24ms/step - loss: 0.4522 - accuracy: 0.9450 - val_loss: 0.5827 - val_accuracy: 0.9302
# Epoch 3/10
# 235/235 [==============================] - 7s 31ms/step - loss: 0.2485 - accuracy: 0.9586 - val_loss: 0.2703 - val_accuracy: 0.9541
# Epoch 4/10
# 235/235 [==============================] - 6s 24ms/step - loss: 0.1816 - accuracy: 0.9674 - val_loss: 0.3198 - val_accuracy: 0.9570
# Epoch 5/10
# 235/235 [==============================] - 6s 27ms/step - loss: 0.1660 - accuracy: 0.9713 - val_loss: 0.2141 - val_accuracy: 0.9656
# Epoch 6/10
# 235/235 [==============================] - 7s 30ms/step - loss: 0.1370 - accuracy: 0.9757 - val_loss: 0.2608 - val_accuracy: 0.9672
# Epoch 7/10
# ...

# %%
model.evaluate(test_data, test_labels_one_hot)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.3377 - accuracy: 0.9696
# [0.337736576795578, 0.9696000218391418]

# %% [markdown]
# # Comparison with Scaled Data vs Without Scaled Data
#
# When using scaled dataset got an accuracy of 98.32%, when using not scaled dataset we got an accuracy of 96.96% reduction in accuracy
